# %% [markdown]
# <a href="https://colab.research.google.com/github/evanstrait/DAFT_1022/blob/main/Module_1/Lab_13_APIs/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import requests

response = requests.get('https://xkcd.com/info.0.json')
results = response.json()
results
# Out:
# {'month': '10',
#  'num': 2686,
#  'link': '',
#  'year': '2022',
#  'news': '',
#  'safe_title': 'Space Adventure',
#  'transcript': '',
#  'alt': '"Sir, it looked really cool." "Oh no--prestige TV. Okay, which of you has a terrible secret that\'s being slowly revealed to the audience through flashbacks? Just spit it out so we can escape this arc!"',
#  'img': 'https://imgs.xkcd.com/comics/space_adventure.png',
#  'title': 'Space Adventure',
#  'day': '17'}

# %%
response = requests.get('https://httpbin.org/get')
results = response.json()
results
# Out:
# {'args': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.23.0',
#   'X-Amzn-Trace-Id': 'Root=1-634eac6c-03007fc04673bf4b7f455d83'},
#  'origin': '34.73.183.47',
#  'url': 'https://httpbin.org/get'}

# %%
response = requests.get('https://api.github.com/search/repositories?q=language:python&sort=stars')
results = response.json()
results
# Out:
# {'total_count': 8540391,
#  'incomplete_results': True,
#  'items': [{'id': 1039520,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxMDM5NTIw',
#    'name': 'youtube-dl',
#    'full_name': 'ytdl-org/youtube-dl',
#    'private': False,
#    'owner': {'login': 'ytdl-org',
#     'id': 48381040,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ4MzgxMDQw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/48381040?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/ytdl-org',
#     'html_url': 'https://github.com/ytdl-org',
#     'followers_url': 'https://api.github.com/users/ytdl-org/followers',
#     'following_url': 'https://api.github.com/users/ytdl-org/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/ytdl-org/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/ytdl-org/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/ytdl-org/subscriptions',
# ...
